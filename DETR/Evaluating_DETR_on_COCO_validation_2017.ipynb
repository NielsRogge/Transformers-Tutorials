# %% [markdown]
# <a href="https://colab.research.google.com/github/NielsRogge/Transformers-Tutorials/blob/master/DETR/Evaluating_DETR_on_COCO_validation_2017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, we are going to evaluate `DetrForObjectDetection` on the COCO 2017 validation set, loaded from the Hugging Face Hub.
#
# A GPU is recommended.

# %% [markdown]
# ## Set up environment
#
# We install Transformers, [timm](https://github.com/huggingface/pytorch-image-models) (used for DETR's convolutional backbone), 🤗 Datasets and pycocotools.

# %%
# %pip install -q transformers torch torchvision timm datasets pycocotools pillow

# %% [markdown]
# ## Load COCO from the Hub
#
# We'll use [`detection-datasets/coco`](https://huggingface.co/datasets/detection-datasets/coco). The full validation split has about 5,000 images; for a quick demo we stream a subset. Increase `NUM_IMAGES` (or iterate the full stream) to evaluate more images.

# %%
from datasets import Dataset, load_dataset
from transformers import DetrForObjectDetection

model_id = "facebook/detr-resnet-50"
model = DetrForObjectDetection.from_pretrained(model_id)
id2label = {int(k): v for k, v in model.config.id2label.items()}
label2id = {v: k for k, v in id2label.items()}

# Map Hub ClassLabel names (80 contiguous classes) onto DETR/COCO category ids (1-90 with gaps).
# Streaming avoids downloading the full ~800MB validation split for a quick demo.
NUM_IMAGES = 100  # increase this to evaluate more images
stream = load_dataset("detection-datasets/coco", split="val", streaming=True)
category_names = stream.features["objects"]["category"].feature.names
hub_to_coco_id = {idx: label2id[name] for idx, name in enumerate(category_names)}

examples = []
for i, example in enumerate(stream):
    examples.append(example)
    if i + 1 >= NUM_IMAGES:
        break

coco = Dataset.from_list(examples)
coco

# %% [markdown]
# We reconstruct a lightweight COCO API so `DetrImageProcessor` and `pycocotools` can consume the Hub examples. Hub boxes are in Pascal VOC `xyxy`; DETR expects COCO `xywh`.

# %% [markdown]
# Category ids are remapped from the Hub's 80 contiguous labels to DETR's COCO ids when we build the COCO API below.

# %%
import os
from pycocotools.coco import COCO
from torch.utils.data import Dataset


class HuggingFaceCocoDetection(Dataset):
    def __init__(self, dataset, image_processor, id2label):
        self.dataset = dataset
        self.image_processor = image_processor
        self.ids = list(dataset["image_id"])
        self.id2index = {image_id: idx for idx, image_id in enumerate(self.ids)}
        self.id2label = id2label
        self.coco = COCO()
        self.coco.dataset = self._build_coco_dataset()
        self.coco.createIndex()

    def _build_coco_dataset(self):
        images = []
        annotations = []
        categories = [{"id": idx, "name": name, "supercategory": "object"} for idx, name in self.id2label.items()]

        for example in self.dataset:
            image = example["image"]
            image_id = example["image_id"]
            file_name = getattr(image, "filename", None) or f"{image_id}.jpg"
            images.append(
                {
                    "id": image_id,
                    "file_name": os.path.basename(file_name),
                    "width": example["width"],
                    "height": example["height"],
                }
            )

            objects = example["objects"]
            for annotation_id, bbox, category_id, area in zip(
                objects["bbox_id"], objects["bbox"], objects["category"], objects["area"]
            ):
                xmin, ymin, xmax, ymax = bbox  # Hub format is Pascal VOC xyxy
                coco_bbox = [xmin, ymin, xmax - xmin, ymax - ymin]
                annotations.append(
                    {
                        "id": int(annotation_id),
                        "image_id": image_id,
                        "category_id": hub_to_coco_id[int(category_id)],
                        "bbox": coco_bbox,
                        "area": float(area),
                        "iscrowd": 0,
                    }
                )

        return {"images": images, "annotations": annotations, "categories": categories}

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        example = self.dataset[idx]
        image = example["image"].convert("RGB")
        image_id = example["image_id"]
        target = {"image_id": image_id, "annotations": self.coco.imgToAnns[image_id]}
        encoding = self.image_processor(images=image, annotations=target, return_tensors="pt")
        pixel_values = encoding["pixel_values"].squeeze()
        target = encoding["labels"][0]
        return pixel_values, target

    def get_image(self, image_id):
        return self.dataset[self.id2index[image_id]]["image"].convert("RGB")

# %%
from transformers import DetrImageProcessor

image_processor = DetrImageProcessor.from_pretrained(model_id)
test_dataset = HuggingFaceCocoDetection(
    dataset=coco,
    image_processor=image_processor,
    id2label=id2label,
)
print(len(test_dataset))

# %% [markdown]
# Let's visualize a random image with its annotations:

# %%
import numpy as np
from PIL import ImageDraw

image_ids = test_dataset.coco.getImgIds()
image_id = image_ids[np.random.randint(0, len(image_ids))]
print("Image n°{}".format(image_id))
image = test_dataset.get_image(image_id)

annotations = test_dataset.coco.imgToAnns[image_id]
draw = ImageDraw.Draw(image, "RGBA")
cats = test_dataset.coco.cats

for annotation in annotations:
    box = annotation["bbox"]
    class_idx = annotation["category_id"]
    x, y, w, h = tuple(box)
    draw.rectangle((x, y, x + w, y + h), outline="red", width=1)
    draw.text((x, y), cats[class_idx]["name"], fill="white")

image

# %% [markdown]
# Next, let's create a corresponding `test_dataloader`. DETR resizes every image with a min size of 800 and a max size of 1333, so images can have different sizes. We pad them in a custom `collate_fn` and create a `pixel_mask` that indicates which pixels are real vs padding.

# %%
from torch.utils.data import DataLoader

def collate_fn(batch):
    pixel_values = [item[0] for item in batch]
    encoding = image_processor.pad(pixel_values, return_tensors="pt")
    labels = [item[1] for item in batch]
    return {
        "pixel_values": encoding["pixel_values"],
        "pixel_mask": encoding["pixel_mask"],
        "labels": labels,
    }

test_dataloader = DataLoader(test_dataset, collate_fn=collate_fn, batch_size=2)
batch = next(iter(test_dataloader))
print(batch.keys())
print(batch["pixel_values"].shape)
print(batch["pixel_mask"].shape)

# %% [markdown]
# ## Run evaluation
#
# We convert DETR's predictions to COCO format and score them with `pycocotools`.

# %%
import torch
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from tqdm.notebook import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

print("Running evaluation...")
all_results = []

for batch in tqdm(test_dataloader):
    pixel_values = batch["pixel_values"].to(device)
    pixel_mask = batch["pixel_mask"].to(device)
    labels = [{k: v.to(device) for k, v in t.items()} for t in batch["labels"]]

    with torch.no_grad():
        outputs = model(pixel_values=pixel_values, pixel_mask=pixel_mask)

    orig_target_sizes = torch.stack([target["orig_size"] for target in labels], dim=0)
    results = image_processor.post_process_object_detection(
        outputs, target_sizes=orig_target_sizes, threshold=0.0
    )

    for target, result in zip(labels, results):
        image_id = target["image_id"].item()
        boxes = result["boxes"].cpu().numpy()
        scores = result["scores"].cpu().numpy()
        labels_pred = result["labels"].cpu().numpy()

        boxes_xywh = boxes.copy()
        boxes_xywh[:, 2] = boxes[:, 2] - boxes[:, 0]
        boxes_xywh[:, 3] = boxes[:, 3] - boxes[:, 1]

        for box, score, label in zip(boxes_xywh, scores, labels_pred):
            all_results.append(
                {
                    "image_id": image_id,
                    "category_id": int(label),
                    "bbox": box.tolist(),
                    "score": float(score),
                }
            )

coco_gt = test_dataset.coco
coco_dt = coco_gt.loadRes(all_results)
coco_eval = COCOeval(coco_gt, coco_dt, "bbox")
coco_eval.evaluate()
coco_eval.accumulate()
coco_eval.summarize()
