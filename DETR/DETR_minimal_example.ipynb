# %% [markdown]
# <a href="https://colab.research.google.com/github/NielsRogge/Transformers-Tutorials/blob/master/DETR/DETR_minimal_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DETR: inference notebook
#
# In this notebook, we are going to run the [DETR](https://huggingface.co/docs/transformers/model_doc/detr) model by Facebook AI on an image of the COCO object detection validation dataset.
#
# ### Quick intro: DETR
# DETR is short for DEtection TRansformer, and consists of a convolutional backbone (ResNet-50 or ResNet-101) followed by an encoder-decoder Transformer. It can be trained end-to-end to perform object detection (and panoptic segmentation). Compared to Faster R-CNN and Mask R-CNN, which rely on region proposals, non-maximum suppression and anchor generation, DETR can be trained end-to-end thanks to a **bipartite matching loss**. I highly recommend [Yannic Kilcher's video](https://www.youtube.com/watch?v=T35ba_VXkMY&t=1693s) if you want to understand how DETR works.
#
# ![DETR architecture](https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/model_doc/detr_architecture.png)
#
# ## Set-up environment
#
# First, we install the required libraries.

# %%
# %pip install -q transformers torch timm pillow matplotlib requests

# %% [markdown]
# ## Prepare the image using `DetrImageProcessor`
#
# Let's use the image of the two cats chilling on a couch once more. It's part of the [COCO](https://cocodataset.org/#home) object detection validation 2017 dataset.

# %%
from PIL import Image
import requests

url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw).convert("RGB")
image

# %% [markdown]
# Let's first apply the regular image preprocessing using `DetrImageProcessor`. The processor will resize the image (minimum size = 800, max size = 1333), and normalize it across the channels using the ImageNet mean and standard deviation.

# %%
from transformers import DetrImageProcessor

processor = DetrImageProcessor.from_pretrained("facebook/detr-resnet-50")
encoding = processor(image, return_tensors="pt")
encoding.keys()

# %%
print(encoding["pixel_values"].shape)

# %% [markdown]
# ## Forward pass
#
# Next, let's send the pixel values and pixel mask through the model. We use the one with a ResNet-50 backbone here (it obtains a box AP of 42.0 on COCO validation 2017).

# %%
from transformers import DetrForObjectDetection
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50")
model.to(device)
model.eval()

with torch.no_grad():
    outputs = model(**{k: v.to(device) for k, v in encoding.items()})

# %% [markdown]
# Let's visualize the results!

# %%
import matplotlib.pyplot as plt

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]


def plot_results(pil_img, scores, labels, boxes, id2label):
    plt.figure(figsize=(16, 10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    for score, label, (xmin, ymin, xmax, ymax), c in zip(
        scores.tolist(), labels.tolist(), boxes.tolist(), colors
    ):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        text = f"{id2label[label]}: {score:0.2f}"
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor="yellow", alpha=0.5))
    plt.axis("off")
    plt.show()

# %%
width, height = image.size
results = processor.post_process_object_detection(
    outputs, target_sizes=[(height, width)], threshold=0.9
)[0]
plot_results(image, results["scores"].cpu(), results["labels"].cpu(), results["boxes"].cpu(), model.config.id2label)

# %% [markdown]
# ## Visualizing attention weights of the last decoder layer
#
# Here we visualize the cross-attention weights of the last decoder layer. This corresponds to visualizing, for each detected object, which part of the image the model was looking at to predict this specific bounding box and class.

# %%
probas = outputs.logits.softmax(-1)[0, :, :-1]
keep = probas.max(-1).values > 0.9
bboxes_scaled = results["boxes"].cpu()

# %%
conv_features = []
hooks = [
    model.model.backbone.conv_encoder.register_forward_hook(
        lambda self, input, output: conv_features.append(output)
    ),
]

with torch.no_grad():
    outputs_with_attn = model(
        **{k: v.to(device) for k, v in encoding.items()},
        output_attentions=True,
    )

for hook in hooks:
    hook.remove()

conv_features = conv_features[0]
dec_attn_weights = outputs_with_attn.cross_attentions[-1]
dec_attn_weights = torch.mean(dec_attn_weights, dim=1).detach().cpu()

# %% [markdown]
# Now let's visualize them:

# %%
h, w = conv_features[-1][0].shape[-2:]

fig, axs = plt.subplots(ncols=len(bboxes_scaled), nrows=2, figsize=(22, 7))
for idx, ax_i, box in zip(keep.nonzero(), axs.T, bboxes_scaled):
    xmin, ymin, xmax, ymax = box.detach().numpy()
    ax = ax_i[0]
    ax.imshow(dec_attn_weights[0, idx].view(h, w))
    ax.axis("off")
    ax.set_title(f"query id: {idx.item()}")
    ax = ax_i[1]
    ax.imshow(image)
    ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                               fill=False, color="blue", linewidth=3))
    ax.axis("off")
    ax.set_title(model.config.id2label[probas[idx].argmax().item()])
fig.tight_layout()

# %% [markdown]
# Note that DETR can also perform panoptic segmentation, by replacing the head on top of the decoder. See the panoptic notebook in this folder.
