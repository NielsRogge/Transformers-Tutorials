# %% [markdown]
# <a href="https://colab.research.google.com/github/NielsRogge/Transformers-Tutorials/blob/master/VideoMAE/Quick_inference_with_VideoMAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Quick inference with VideoMAE
#
# In this notebook we run [VideoMAE](https://huggingface.co/docs/transformers/model_doc/videomae) on a short clip and classify the action.
#
# VideoMAE is a Vision Transformer pre-trained with a masked autoencoding objective on videos. After fine-tuning on [Kinetics-400](https://www.deepmind.com/open-source/kinetics), it can recognize 400 human actions.
#
# * Paper: https://arxiv.org/abs/2203.12602
# * Original repo: https://github.com/MCG-NJU/VideoMAE

# %% [markdown]
# ## Set-up environment
#
# First, we install 🤗 Transformers and [PyAV](https://github.com/PyAV-Org/PyAV), which we'll use to decode the video.

# %%
# %pip install -q transformers torch av huggingface_hub pillow

# %% [markdown]
# ## Load video
#
# Let's load a video from the [Kinetics-400](https://www.deepmind.com/open-source/kinetics) dataset. This clip shows someone eating spaghetti.

# %%
from huggingface_hub import hf_hub_download
from IPython.display import Video

video_path = hf_hub_download(
    repo_id="nielsr/video-demo",
    filename="eating_spaghetti.mp4",
    repo_type="dataset",
)
Video(video_path, width=500)

# %% [markdown]
# ## Prepare video for the model
#
# The Kinetics-fine-tuned VideoMAE checkpoints expect 16 frames. We'll sample them with PyAV, then let `VideoMAEImageProcessor` resize, center-crop and normalize each frame.

# %%
import av
import numpy as np

np.random.seed(0)


def sample_frame_indices(clip_len, frame_sample_rate, seg_len):
    converted_len = int(clip_len * frame_sample_rate)
    end_idx = np.random.randint(converted_len, seg_len)
    start_idx = end_idx - converted_len
    indices = np.linspace(start_idx, end_idx, num=clip_len)
    return np.clip(indices, start_idx, end_idx - 1).astype(np.int64)


def read_video_pyav(container, indices):
    frames = []
    container.seek(0)
    start_index = indices[0]
    end_index = indices[-1]
    for i, frame in enumerate(container.decode(video=0)):
        if i > end_index:
            break
        if i >= start_index and i in indices:
            frames.append(frame.to_ndarray(format="rgb24"))
    return np.stack(frames)


container = av.open(video_path)
total_frames = container.streams.video[0].frames
indices = sample_frame_indices(clip_len=16, frame_sample_rate=4, seg_len=total_frames)
video = read_video_pyav(container, indices)
print(video.shape)

# %%
from transformers import VideoMAEImageProcessor

model_id = "MCG-NJU/videomae-large-finetuned-kinetics"
image_processor = VideoMAEImageProcessor.from_pretrained(model_id)
inputs = image_processor(list(video), return_tensors="pt")
print(inputs["pixel_values"].shape)

# %% [markdown]
# ## Load model
#
# Next, let's load the model and move it to the GPU, if it's available.

# %%
from transformers import VideoMAEForVideoClassification
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = VideoMAEForVideoClassification.from_pretrained(model_id).to(device)
model.eval()

# %% [markdown]
# ## Forward pass

# %%
pixel_values = inputs["pixel_values"].to(device)

with torch.no_grad():
    outputs = model(pixel_values)
    logits = outputs.logits

predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
